# %% [markdown]
# <a href="https://colab.research.google.com/github/chocoelf/aiffel_quest/blob/main/AIFFEL_quest/Python_quest/Quest02/2_gram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os import close
import operator
with open('/content/drive/MyDrive/Colab Notebooks/Avengers.txt', 'rt') as text:
  text = text.read()
  text = text.lower()
  text = text.replace('\n', ' ')
  text = text.replace(',', '')
  text = text.replace('.', '')
  text = text.replace('?', '')
  text = text.replace('!', '')
  text = text.replace('"', '')
  text = text.replace("'", ' ')
  text = text.replace('(', '')
  text = text.replace(')', '')
  text = text.replace('-', '')
  text = text.split(" ")
  print(text)

  gen = [text[i] + "," + text[i + 1] for i in range(len(text) - 1)]
  count = 0
  diction = {}
  for g in gen:
    for i in gen:
      if g == i:
        count += 1
        gen.remove(i)
    diction.setdefault(g,count)
    print(g + " = " + str(count))
    count = 0
  print(max(diction.items(), key=operator.itemgetter(1)))
# Out:
# ['the', 'tesseract', 'has', 'awakened', 'it', 'is', 'on', 'a', 'neutral', 'world', 'a', 'human', 'world', 'they', 'wield', 'its', 'power', 'but', 'our', 'ally', 'knows', 'it', 's', 'working', 'so', 'that', 'they', 'never', 'will', 'learn', 'he', 's', 'ready', 'to', 'lead', 'and', 'our', 'force', 'our', 'chitauri', 'will', 'follow', 'the', 'world', 'will', 'be', 'his', 'and', 'the', 'universe', 'yours', 'and', 'the', 'humans', 'what', 'can', 'they', 'do', 'but', 'burn', 'how', 'bad', 'is', 'it', 'that', 's', 'the', 'problem', 'sir', 'we', 'don', 't', 'know', 'dr', 'selvig', 'read', 'an', 'energy', 'surge', 'from', 'the', 'tesseract', 'four', 'hour', 'ago', 'nasa', 'didn', 't', 'authorize', 'selvig', 'to', 'pull', 'the', 'test', 'phase', 'he', 'wasn', 't', 'testing', 'it', 'he', 'wasn', 't', 'even', 'in', 'the', 'room', 'spontaneous', 'advancement', 'it', 'just', 'turned', 'itself', 'on', 'what', 'are', 'the', 'engine', 'levels', 'now', 'climbing', 'when', 'selvig', 'couldn', 't', 'shu
# ...
