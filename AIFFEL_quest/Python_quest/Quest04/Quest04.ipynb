# %% [markdown]
# <a href="https://colab.research.google.com/github/chocoelf/aiffel_quest/blob/main/AIFFEL_quest/Python_quest/Quest04/Quest04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from math import *

'''def input_num():
      num1 = input("첫번째 정수를 입력하세요: ")
      num2 = input("두번째 정수를 입력하세요: ")
      op = input("연산자를 입력하세요: ")

      calcul(num1, num2)
      op_check(op)
      ZeroDivisionError_check(num2_int)

def calcul(x, y):

    try:
      global num1_int
      global num2_int

      if num1.isdigit() and num2.isdigit():
        num1_int = int(num1)
        num2_int = int(num2)

    except:
      print("잘못된 입력입니다. 정수를 입력해 주세요!!")
      input_num()


def ZeroDivisionError_check(num2_int):

  try:
    if num2_int == 0:
      raise ZeroDivisionError('다시 입력해 주세요. ')
  except ZeroDivisionError:
    print("0으로 나눌 수 없습니다.")
    input_num()


def op_check(op):
    list_op = ['+', '-', '*', '/', '**']
    try:
      if op not in list_op:
        raise Exception
    except:
      print("지원하지 않는 연산자입니다.")
      input_num()


def calcul_op(num1_int, num2_int, op):

    if op == '+':
      add(num1_int, num2_int)
    elif op == '-':
      sub(num1_int, num2_int)
    elif op == '*':
      mul(num1_int, num2_int)
    elif op == '/':
      div(num1_int, num2_int)
    else:
      pow(num1_int, num2_int)


    def add(x, y):
      return x + y

    def sub(x, y):
      return x - y

    def mul(x, y):
      return x * y

    def div(x, y):
      return x / y

    def pow(x, y):
      return x ** y

input_num()
calcul_op(num1_int, num2_int, op)'''



def input_num():
    num1 = input("첫번째 정수를 입력하세요: ")
    num2 = input("두번째 정수를 입력하세요: ")
    op = input("연산자를 입력하세요: ")

    calcul(num1, num2, op)

def calcul(x, y, op):
    try:
        num1_int = int(x)
        num2_int = int(y)

        op_check(op)
        ZeroDivisionError_check(num2_int)

        calcul_op(num1_int, num2_int, op)

    except ValueError:
        print("잘못된 입력입니다. 정수를 입력해 주세요!!")
        input_num()

def ZeroDivisionError_check(num2_int):
    if num2_int == 0:
        print("0으로 나눌 수 없습니다.")
        input_num()

def op_check(op):
    list_op = ['+', '-', '*', '/', '**']
    if op not in list_op:
        print("지원하지 않는 연산자입니다.")
        input_num()

def calcul_op(num1_int, num2_int, op):
    if op == '+':
        print(add(num1_int, num2_int))
    elif op == '-':
        print(sub(num1_int, num2_int))
    elif op == '*':
        print(mul(num1_int, num2_int))
    elif op == '/':
        print(div(num1_int, num2_int))
    elif op == '**':
        print(pow(num1_int, num2_int))

    result = input ("계속 계산기를 사용하시겠습니까?")
    if result == "예":
      input_num()
    else:
      print("계산기를 종료합니다.")

def add(x, y):
    return x + y

def sub(x, y):
    return x - y

def mul(x, y):
    return x * y

def div(x, y):
    return x / y

def pow(x, y):
    return x ** y

input_num()
# Out:
# 잘못된 입력입니다. 정수를 입력해 주세요!!
# 잘못된 입력입니다. 정수를 입력해 주세요!!
