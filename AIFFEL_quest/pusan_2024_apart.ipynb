# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = "/content/drive/MyDrive/부산 아파트(매매)_실거래가.txt"
df_test = pd.read_csv(file_path)
df_test
# Out:
#           NO                시군구      번지   본번   부번     단지명  전용면적(㎡)    계약년월  \
# 0          1  부산광역시 기장군 기장읍 동부리   377-2  377    2    동산백조  71.6100  202401
# 1          2  부산광역시 기장군 기장읍 동부리   362-3  362    3  선아베스트빌  81.6900  202401
# 2          3  부산광역시 기장군 기장읍 동부리   377-1  377    1   부전베스트  75.1200  202401
# 3          4  부산광역시 기장군 기장읍 동부리   151-5  151    5      한신  59.8500  202401
# 4          5  부산광역시 기장군 기장읍 동부리   377-2  377    2    동산백조  71.6100  202401
# ...      ...                ...     ...  ...  ...     ...      ...     ...
# 11999  12000      부산광역시 사상구 엄궁동   680-2  680    2  쌍용스윗닷홈  59.9349  202406
# 12000  12001      부산광역시 사상구 엄궁동    35-1   35    1      엄궁  42.3000  202406
# 12001  12002      부산광역시 사상구 엄궁동       1    1    0    무학다솜  59.9800  202406
# 12002  12003      부산광역시 사상구 엄궁동   669-2  669    2    엄궁대림  59.8500  202406
# 12003  12004      부산광역시 사상구 엄궁동  25-110   25  110    엄궁럭키  82.6000  202406
#
#        계약일 거래금액(만원)    동   층 매수자 매도자  건축년도             도로명 해제사유발생일  거래유형  \
# 0        2   12,800    1   2  개인  개인  1991  차성동로142번길 12-8       -  중개거래
# 1        8   18,000    -   6  개인  개인  2002    차성동로102번길 11       -  중개거래
# 2       12   11,000    B   3  개인  개인  1990  차성동로142번길 12-2       -  중개거래
# 3       15   15,200  103   8  개인  개인  1995     차성로344번길 13       -  중개거래
# 4       22   12,200    1   3  개인  개인  1991  차성동로142번길 12-8       -  중개거래
# ...    ...      ...  ...  ..  ..  ..   ...             ...     ...   ...
# 11999    9   19,000    -   4  개인  개인  2005         엄궁로 100       -  중개거래
# 12000    9   10,000    -   4  개인  개인  1983         엄궁로 202       -  중개거래
# 12001   10   14,800    -  16  개인  개인  2000      대동로64번길 22       -  중개거래
# 12002   16   16,300    -  11  개인  개인  1999         엄궁로 158       -  중개거래
# 12003   19   15,000    -   9  개인  개인  1993       대동로 34-25       -  중개거래
#
#        중개사소재지      등기일자
# 0      부산 기장군  24.01.16
# 1      부산 기장군  24.04.30
# 2      부산 기장군  24.02.23
# 3      부산 기장군  24.01.19
# 4      부산 기장군  24.02.06
# ...       ...       ...
# 11999  부산 사상구         -
# 12000  부산 사상구         -
# 12001  부산 사상구         -
# 12002  부산 사상구         -
# 12003  부산 사상구         -
#
# [12004 rows x 20 columns]

# %%
df_test = df_test.drop(['NO', '본번', '부번', '계약일', '동', '매수자', '매도자', '도로명', '해제사유발생일', '거래유형', '중개사소재지', '등기일자'], axis = 1)

# %%
df_test['주소'] = df_test['시군구'] + " " + df_test['번지']

# %%
df_test
# Out:
#                      시군구      번지     단지명  전용면적(㎡)    계약년월 거래금액(만원)   층  건축년도  \
# 0      부산광역시 기장군 기장읍 동부리   377-2    동산백조  71.6100  202401   12,800   2  1991
# 1      부산광역시 기장군 기장읍 동부리   362-3  선아베스트빌  81.6900  202401   18,000   6  2002
# 2      부산광역시 기장군 기장읍 동부리   377-1   부전베스트  75.1200  202401   11,000   3  1990
# 3      부산광역시 기장군 기장읍 동부리   151-5      한신  59.8500  202401   15,200   8  1995
# 4      부산광역시 기장군 기장읍 동부리   377-2    동산백조  71.6100  202401   12,200   3  1991
# ...                  ...     ...     ...      ...     ...      ...  ..   ...
# 11999      부산광역시 사상구 엄궁동   680-2  쌍용스윗닷홈  59.9349  202406   19,000   4  2005
# 12000      부산광역시 사상구 엄궁동    35-1      엄궁  42.3000  202406   10,000   4  1983
# 12001      부산광역시 사상구 엄궁동       1    무학다솜  59.9800  202406   14,800  16  2000
# 12002      부산광역시 사상구 엄궁동   669-2    엄궁대림  59.8500  202406   16,300  11  1999
# 12003      부산광역시 사상구 엄궁동  25-110    엄궁럭키  82.6000  202406   15,000   9  1993
#
#                             주소
# 0      부산광역시 기장군 기장읍 동부리 377-2
# 1      부산광역시 기장군 기장읍 동부리 362-3
# 2      부산광역시 기장군 기장읍 동부리 377-1
# 3      부산광역시 기장군 기장읍 동부리 151-5
# 4      부산광역시 기장군 기장읍 동부리 377-2
# ...                        ...
# 11999      부산광역시 사상구 엄궁동 680-2
# 12000       부산광역시 사상구 엄궁동 35-1
# 12001          부산광역시 사상구 엄궁동 1
# 12002      부산광역시 사상구 엄궁동 669-2
# 12003     부산광역시 사상구 엄궁동 25-110
#
# [12004 rows x 9 columns]

# %%
df_test = df_test.drop(['시군구', '번지'], axis = 1)

# %%
df_test
# Out:
#           단지명  전용면적(㎡)    계약년월 거래금액(만원)   층  건축년도                       주소
# 0        동산백조  71.6100  202401   12,800   2  1991  부산광역시 기장군 기장읍 동부리 377-2
# 1      선아베스트빌  81.6900  202401   18,000   6  2002  부산광역시 기장군 기장읍 동부리 362-3
# 2       부전베스트  75.1200  202401   11,000   3  1990  부산광역시 기장군 기장읍 동부리 377-1
# 3          한신  59.8500  202401   15,200   8  1995  부산광역시 기장군 기장읍 동부리 151-5
# 4        동산백조  71.6100  202401   12,200   3  1991  부산광역시 기장군 기장읍 동부리 377-2
# ...       ...      ...     ...      ...  ..   ...                      ...
# 11999  쌍용스윗닷홈  59.9349  202406   19,000   4  2005      부산광역시 사상구 엄궁동 680-2
# 12000      엄궁  42.3000  202406   10,000   4  1983       부산광역시 사상구 엄궁동 35-1
# 12001    무학다솜  59.9800  202406   14,800  16  2000          부산광역시 사상구 엄궁동 1
# 12002    엄궁대림  59.8500  202406   16,300  11  1999      부산광역시 사상구 엄궁동 669-2
# 12003    엄궁럭키  82.6000  202406   15,000   9  1993     부산광역시 사상구 엄궁동 25-110
#
# [12004 rows x 7 columns]

# %%
df_test['계약년월'] = df_test['계약년월'].astype(str)

# %%
df_test
# Out:
#           단지명  전용면적(㎡)    계약년월 거래금액(만원)   층  건축년도                       주소
# 0        동산백조  71.6100  202401   12,800   2  1991  부산광역시 기장군 기장읍 동부리 377-2
# 1      선아베스트빌  81.6900  202401   18,000   6  2002  부산광역시 기장군 기장읍 동부리 362-3
# 2       부전베스트  75.1200  202401   11,000   3  1990  부산광역시 기장군 기장읍 동부리 377-1
# 3          한신  59.8500  202401   15,200   8  1995  부산광역시 기장군 기장읍 동부리 151-5
# 4        동산백조  71.6100  202401   12,200   3  1991  부산광역시 기장군 기장읍 동부리 377-2
# ...       ...      ...     ...      ...  ..   ...                      ...
# 11999  쌍용스윗닷홈  59.9349  202406   19,000   4  2005      부산광역시 사상구 엄궁동 680-2
# 12000      엄궁  42.3000  202406   10,000   4  1983       부산광역시 사상구 엄궁동 35-1
# 12001    무학다솜  59.9800  202406   14,800  16  2000          부산광역시 사상구 엄궁동 1
# 12002    엄궁대림  59.8500  202406   16,300  11  1999      부산광역시 사상구 엄궁동 669-2
# 12003    엄궁럭키  82.6000  202406   15,000   9  1993     부산광역시 사상구 엄궁동 25-110
#
# [12004 rows x 7 columns]

# %%
df_test.drop(['단지명'], axis = 1)
# Out:
#        전용면적(㎡)    계약년월 거래금액(만원)   층  건축년도                       주소
# 0      71.6100  202401   12,800   2  1991  부산광역시 기장군 기장읍 동부리 377-2
# 1      81.6900  202401   18,000   6  2002  부산광역시 기장군 기장읍 동부리 362-3
# 2      75.1200  202401   11,000   3  1990  부산광역시 기장군 기장읍 동부리 377-1
# 3      59.8500  202401   15,200   8  1995  부산광역시 기장군 기장읍 동부리 151-5
# 4      71.6100  202401   12,200   3  1991  부산광역시 기장군 기장읍 동부리 377-2
# ...        ...     ...      ...  ..   ...                      ...
# 11999  59.9349  202406   19,000   4  2005      부산광역시 사상구 엄궁동 680-2
# 12000  42.3000  202406   10,000   4  1983       부산광역시 사상구 엄궁동 35-1
# 12001  59.9800  202406   14,800  16  2000          부산광역시 사상구 엄궁동 1
# 12002  59.8500  202406   16,300  11  1999      부산광역시 사상구 엄궁동 669-2
# 12003  82.6000  202406   15,000   9  1993     부산광역시 사상구 엄궁동 25-110
#
# [12004 rows x 6 columns]

# %%
# !pip install googlemaps
# Out:
# Collecting googlemaps
#   Downloading googlemaps-4.10.0.tar.gz (33 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests<3.0,>=2.20.0 in /usr/local/lib/python3.10/dist-packages (from googlemaps) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (2024.6.2)
# Building wheels for collected packages: googlemaps
#   Building wheel for googlemaps (setup.py) ... done
#   Created wheel for googlemaps: filename=googlemaps-4.10.0-py3-none-any.whl size=40712 sha256=061df0fea8c1f3ff7c3b7ad05a6b0acfe3615599162a8d2239c442d23b902005
#   Stored in directory: /root/.cache/pip/wheels/17/f8/79/999d5d37118fd35d7219ef57933eb9d09886c4c4503a800f84
# Successfully built googlemaps
# Installing collected packages: googlemaps
# Successfully installed googlemaps-4.10.0

# %%
import googlemaps

my_key = 'AIzaSyBS9a-Muj586HVGy5093yZX8QMcyaWDNTk'
maps = googlemaps.Client(key=my_key)

# %%
unique_nan_addresses = df_test['주소'].unique()
location_dict = {}

def get_geocode(address):
    try:
        geo_loc = maps.geocode(address)
        lat = geo_loc[0]['geometry']['location']['lat']
        lng = geo_loc[0]['geometry']['location']['lng']
        return [lat,lng]
    except:
        return [None, None]

for address in unique_nan_addresses:
    location = get_geocode(address)
    location_dict[address] = (location[0], location[1])

# %%
print(location_dict)
# Out:
# {'부산광역시 기장군 기장읍 동부리 377-2': (35.2496486, 129.2181731), '부산광역시 기장군 기장읍 동부리 362-3': (35.2469402, 129.2175686), '부산광역시 기장군 기장읍 동부리 377-1': (35.2501235, 129.2181468), '부산광역시 기장군 기장읍 동부리 151-5': (35.2488042, 129.2153372), '부산광역시 기장군 기장읍 동부리 333': (35.2472436, 129.2114534), '부산광역시 기장군 기장읍 동부리 159-10': (35.2462369, 129.2159376), '부산광역시 기장군 기장읍 동부리 509': (35.2485605, 129.2114274), '부산광역시 기장군 기장읍 동부리 374-11': (35.2483023, 129.2185463), '부산광역시 기장군 기장읍 동부리 335-9': (35.2468209, 129.2115228), '부산광역시 기장군 기장읍 동부리 117-3': (35.2470556, 129.212686), '부산광역시 기장군 기장읍 교리 2': (35.256903, 129.2190597), '부산광역시 기장군 기장읍 교리 251-3': (35.2547034, 129.218305), '부산광역시 기장군 기장읍 교리 14-5': (35.255348, 129.2183902), '부산광역시 기장군 기장읍 교리 65': (35.2562723, 129.2150817), '부산광역시 기장군 기장읍 교리 360-2': (35.2533369, 129.2196118), '부산광역시 기장군 기장읍 교리 268': (35.2544604, 129.2198722), '부산광역시 기장군 기장읍 교리 336-10': (35.2521082, 129.2153533), '부산광역시 기장군 기장읍 교리 371': (35.2523591, 129.2194239), '부산광역시 기장군 기장읍 교리 343-1': (35.2529763, 129.2163798), '부산광역시 기장군 기장읍 교리 160-1': (35.2559944, 129.2123353), '부산광역시 기장군 기장읍 서부리 101': (35.24471339999999, 129.209454), '부산광역시 기장군 기장읍 서부리 402': (35.2512378, 129.2095824), '부산광역시 기장군 기장읍 대라리 251': (35.2385554, 129.2108387), '부산광역시 기장군 기장읍 대라리 85': (35.2416804, 129.2163015), '부산광역시 기장군 기장읍 대라리 240': (35.2379443, 129.2094329), '부산광역시 기장군 기장읍 대라리 128-11': (35.2398935, 129.2138613), '부산광역시 기장군 기장읍 대라리 89-2': (35.2421725, 129.2171426), '부산광역시 기장군 기장읍 대라리 172-12': (35.2364314, 129.2147289), '부산광역시 기장군 기장읍 대라리 172-6': (35.2361736, 129.2145736), '부산광역시 기장군 기장읍 대라리 126-2': (35.2416147, 129.2149553), '부산광역시 기장군 기장읍 대라리 126-12': (35.2413772, 129.2149232), '부산광역시 기장군 기장읍 대라리 905': (35.2407822, 129.2079916), '부산광역시 기장군 기장읍 대라리 148-6': (35.2385352, 129.2145681), '부산광역시 기장군 기장읍 대라리 925': (35.2408092, 129.2085433), '부산광역시 기장군 기장읍 대라리 165-14': (35.2376115, 129.2128568), '부산광역시 기장군 기장읍 대라리 643-1': (35.2384655, 129.2090383), '부산광역시 기장군 기장읍 대라리 1024': (35.2417818, 129.2117584), '부산광역시 기장군 기장읍 대라리 112-1': (35.2412727, 129.2158555), '부산광역시 기장군 기장읍 대라리 178-3': (35.2362315, 129.2122161), '부산광역시 기장군 기장읍 대라리 100-1': (35.2401211, 129.2168393), '부산광역시 기장군 기장읍 대라리 408-2': (35.2415657, 129.2138772), '부산광역시 기장군 기장읍 대라리 97-6': (35.2413712, 129.2173256), '부산광역시 기장군 기장읍 대라리 81-8': (35.2419365, 129.2161405), '부산광역시 기장군 기장읍 대라리 160-7': (35.2369575, 129.2106708), '부산광역시 기장군 기장읍 청강리 18-2': (35.2445668, 129.219932), '부산광역시 기장군 기장읍 청강리 868': (35.2291433, 129.2143987), '부산광역시 기장군 기장읍 청강리 291-7': (35.2373391, 129.2182387), '부산광역시 기장군 기장읍 청강리 333': (35.2334495, 129.2177064), '부산광역시 기장군 기장읍 청강리 144': (35.2388418, 129.2228217), '부산광역시 기장군 기장읍 청강리 258': (35.2372111, 129.219019), '부산광역시 기장군 기장읍 대변리 647': (35.2255239, 129.2265802), '부산광역시 기장군 기장읍 내리 792': (35.2030815, 129.2076445), '부산광역시 기장군 기장읍 내리 776': (35.2034514, 129.2054678), '부산광역시 기장군 장안읍 명례리 924-12': (35.3684758, 129.255871), '부산광역시 기장군 정관읍 방곡리 380': (35.3275331, 129.189778), '부산광역시 기장군 정관읍 방곡리 385': (35.3258208, 129.1880987), '부산광역시 기장군 정관읍 방곡리 405': (35.3237435, 129.1889531), '부산광역시 기장군 정관읍 방곡리 407': (35.3221621, 129.1895661), '부산광역시 기장군 정관읍 방곡리 378': (35.3276324, 129.1883923), '부산광역시 기장군 정관읍 매학리 723': (35.3190984, 129.1751695), '부산광역시 기장군 정관읍 매학리 41': (35.32355100000001, 129.1793459), '부산광역시 기장군 정관읍 달산리 139': (35.3220298, 129.1960535), '부산광역시 기장군 정관읍 달산리 1199': (35.3202426, 129.1856887), '부산광역시 기장군 정관읍 달산리 1207': (35.318861, 129.189828), '부산광역시 기장군 정관읍 달산리 1244': (35.3209527, 129.1959397), '부산광역시 기장군 정관읍 달산리 141-5': (35.3219532, 129.1943917), '부산광역시 기장군 정관읍 모전리 735': (35.3340612, 129.1637413), '부산광역시 기장군 정관읍 모전리 776': (35.3298181, 129.1658322), '부산광역시 기장군 정관읍 모전리 723': (35.3387132, 129.1639225), '부산광역시 기장군 정관읍 모전리 728': (35.3372432, 129.1661737), '부산광역시 기장군 정관읍 모전리 759': (35.3310229, 129.1688288), '부산광역시 기장군 정관읍 모전리 730': (35.335776, 129.1629367), '부산광역시 기장군 정관읍 모전리 755': (35.3334187, 129.1681057), '부산광역시 기장군 정관읍 용수리 1387': (35.3241099, 129.1695991), '부산광역시 기장군 정관읍 용수리 1275': (35.3297754, 129.1803318), '부산광역시 기장군 정관읍 용수리 1403': (35.3214435 ...

# %%
print(unique_nan_addresses)
# Out:
# ['부산광역시 기장군 기장읍 동부리 377-2' '부산광역시 기장군 기장읍 동부리 362-3'
#  '부산광역시 기장군 기장읍 동부리 377-1' ... '부산광역시 사상구 엄궁동 183' '부산광역시 사상구 엄궁동 11-41'
#  '부산광역시 사상구 엄궁동 1']

# %%
len(unique_nan_addresses)
# Out:
# 1981

# %%
unique_test = maps.geocode('부산광역시 기장군 기장읍 동부리 377-2')
print(unique_test)
# Out:
# [{'address_components': [{'long_name': '377-2', 'short_name': '377-2', 'types': ['premise']}, {'long_name': 'Dongbu-ri', 'short_name': 'Dongbu-ri', 'types': ['political', 'sublocality', 'sublocality_level_3']}, {'long_name': 'Gijang-eup', 'short_name': 'Gijang-eup', 'types': ['political', 'sublocality', 'sublocality_level_2']}, {'long_name': 'Gijang', 'short_name': 'Gijang', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Busan', 'short_name': 'Busan', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'South Korea', 'short_name': 'KR', 'types': ['country', 'political']}, {'long_name': '46063', 'short_name': '46063', 'types': ['postal_code']}], 'formatted_address': '377-2 Dongbu-ri, Gijang-eup, Gijang, Busan, South Korea', 'geometry': {'location': {'lat': 35.2496486, 'lng': 129.2181731}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 35.2509975802915, 'lng': 129.2195220802915}, 'southwest': {'lat': 35.2482996197085, 'lng': 129.2168241197085}}}, 'place_id': 'ChIJ5xYrRj6PaDUREF52o0J3QDQ', 'plus_code': {'compound_code': '66X9+V7 Busan, South Korea', 'global_code': '8Q7F66X9+V7'}, 'types': ['street_address']}]

# %%
unique_test[0]['geometry']['location']
# Out:
# {'lat': 35.2496486, 'lng': 129.2181731}

# %%
df_test = df_test.drop(['top10', 'Name'], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-1d445c81c765> in <cell line: 1>()
# ----> 1 df_test = df_test.drop(['top10', 'Name'], axis = 1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5256                 weight  1.0     0.8
#    5257         """
# -> 5258         return super().drop(
#    5259             labels=labels,
#    5260             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547         for axis, labels in axes.items():
#    4548             if labels is not None:
# -> 4549                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4550
#    4551         if inplace:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4589                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4590             else:
# -> 4591                 new_axis = axis.drop(labels, errors=errors)
#    4592             indexer = axis.get_indexer(new_axis)
#    4593
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6697         if mask.any():
#    6698             if errors != "ignore":
# -> 6699                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700             indexer = indexer[~mask]
#    6701         return self.delete(indexer)
#
# KeyError: "['top10', 'Name'] not found in axis"

# %%
# Check for existing columns before dropping
print(df_test.columns)

# Drop only the columns that exist in the DataFrame
existing_columns_to_drop = [col for col in ['top10', 'Name'] if col in df_test.columns]
if existing_columns_to_drop:
    df_test = df_test.drop(existing_columns_to_drop, axis=1)
# Out:
# Index(['단지명', '전용면적(㎡)', '계약년월', '거래금액(만원)', '층', '건축년도', '주소'], dtype='object')

# %%
df_test
# Out:
#           단지명  전용면적(㎡)    계약년월 거래금액(만원)   층  건축년도                       주소
# 0        동산백조  71.6100  202401   12,800   2  1991  부산광역시 기장군 기장읍 동부리 377-2
# 1      선아베스트빌  81.6900  202401   18,000   6  2002  부산광역시 기장군 기장읍 동부리 362-3
# 2       부전베스트  75.1200  202401   11,000   3  1990  부산광역시 기장군 기장읍 동부리 377-1
# 3          한신  59.8500  202401   15,200   8  1995  부산광역시 기장군 기장읍 동부리 151-5
# 4        동산백조  71.6100  202401   12,200   3  1991  부산광역시 기장군 기장읍 동부리 377-2
# ...       ...      ...     ...      ...  ..   ...                      ...
# 11999  쌍용스윗닷홈  59.9349  202406   19,000   4  2005      부산광역시 사상구 엄궁동 680-2
# 12000      엄궁  42.3000  202406   10,000   4  1983       부산광역시 사상구 엄궁동 35-1
# 12001    무학다솜  59.9800  202406   14,800  16  2000          부산광역시 사상구 엄궁동 1
# 12002    엄궁대림  59.8500  202406   16,300  11  1999      부산광역시 사상구 엄궁동 669-2
# 12003    엄궁럭키  82.6000  202406   15,000   9  1993     부산광역시 사상구 엄궁동 25-110
#
# [12004 rows x 7 columns]

# %%
# df_test['위도'] = df_test.apply(lambda row: location_dict[row['주소']] if pd.isna(row['위도']) else row['위도'], axis=1)
# df_test['경도'] = df_test.apply(lambda row: location_dict[row['주소']] if pd.isna(row['경도']) else row['경도'], axis=1)

df_test['위도'] = df_test['주소'].apply(lambda x: location_dict[x][0])
df_test['경도'] = df_test['주소'].apply(lambda x: location_dict[x][1])

# %%
df_test.to_csv('./data_add_address_test_seoul.csv')

# %%
df_test['위도'].iloc()[0] - df_test['위도'].iloc()[1]
# Out:
# 0.002708400000003053
